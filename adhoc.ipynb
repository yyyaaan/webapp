# %%
from httpx import AsyncClient

# %%
url_base = "https://yan-2820797191394638.aws.databricksapps.com"
# url_base = "http://localhost:8001"

# %%
async with AsyncClient() as client:
    r = await client.get(
        url=f"{url_base}/api/v3/system/users/summary",
        headers={
            "Authorization": "Bearer sk-"
        }
    )

print(r.status_code)
print(r.text)
# Out:
# 401
# {}
